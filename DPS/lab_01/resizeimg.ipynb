# %%
from PIL import Image

# %%
img = Image.open("../static/bl2049.jpg", "r")
print(img.size)
# Out:
# (3200, 1808)

# %%
img1 = img.resize((int(img.size[0]/4), int(img.size[1]/4)))
display(img1)
# Out:
# <PIL.Image.Image image mode=RGB size=800x452 at 0x29042611760>

# %%
img2.save("../static/bl2049_small", "JPEG")

# %%
from datetime import datetime as dt

# %%
for i in range(10):
    print(str(dt.timestamp(dt.now())).replace('.', ''))
# Out:
# 1654963627538605
# 1654963627538605
# 1654963627538605
# 1654963627538605
# 1654963627538605
# 1654963627538605
# 1654963627538605
# 1654963627538605
# 1654963627538605
# 1654963627538605

# %%
img2 = Image.open("../static/sun-shadow-book-page.jpg", "r")
print(img2.size)
# Out:
# (1936, 2592)

# %%
img3 = img2.resize((int(img2.size[0]/4), int(img2.size[1]/4)))
display(img3)
# Out:
# <PIL.Image.Image image mode=RGB size=484x648 at 0x23E1F6717F0>

# %%
img3.save("../static/bs_small", "JPEG")

# %%
def resizeImg(path_to, name):
    img = Image.open(path_to, "r")
    print(img.size)
    img2 = img.resize((int(img.size[0]/4), int(img.size[1]/4)))
    display(img2)
    img2.save("../static/"+name+".jpg", "JPEG")

# %%
resizeImg(r"..\static\bird.jpg", "bird_small")
# Out:
# (1800, 1350)
# <PIL.Image.Image image mode=RGB size=450x337 at 0x1FF7BAD1EE0>
